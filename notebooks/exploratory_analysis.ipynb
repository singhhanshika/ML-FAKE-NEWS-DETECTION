# %% [markdown]
# # Fake News Dataset Exploration
#
# Run `python train.py` first. This notebook reads generated, duplicate-safe processed data; production analysis lives in `src/fake_news_detector/eda.py` so it is reproducible.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
news = pd.read_csv(root / 'data' / 'processed' / 'news.csv')
news.groupby(['split', 'label']).size().unstack(fill_value=0)

# %%
news[['word_count', 'label']].groupby('label').describe().round(2)
